# %%
# --- FASE 1: PENYESUAIAN TARGET VARIABLE ---
df_master = df_merged.copy()

df_master = df_master.dropna(subset=['market_value_in_eur'])


# --- FASE 2: FEATURE ENGINEERING (INOVASI UTS) ---
df_master['minutes_played_safe'] = df_master['total_minutes'].replace(0, 1)

# Membuat rasio performa per-90-menit (fitur baru yang lebih objektif)
df_master['goals_per_90'] = (df_master['total_goals'] / df_master['minutes_played_safe']) * 90
df_master['assists_per_90'] = (df_master['total_assists'] / df_master['minutes_played_safe']) * 90

# Membulatkan nilai desimal agar rapi (2 angka di belakang koma)
df_master['goals_per_90'] = df_master['goals_per_90'].round(2)
df_master['assists_per_90'] = df_master['assists_per_90'].round(2)

# Membuang kolom sementara
df_master = df_master.drop(columns=['minutes_played_safe'])


# --- FASE 3: EXPORT KE PROCESSED DATA ---
import os
os.makedirs('../data/processed', exist_ok=True) # Memastikan folder benar-benar ada

output_path = '../data/processed/mercato_engineered_data.csv'
df_master.to_csv(output_path, index=False)

print(f"✅ PROSES SELESAI. Dataset final berisi {len(df_master)} pemain modern siap digunakan.")
print(f"✅ File berhasil disimpan sebagai artifact di: {output_path}")

# Menampilkan hasil akhir dengan kolom yang pasti ada
df_master[['name', 'position', 'total_minutes', 'goals_per_90', 'assists_per_90', 'market_value_in_eur']].head()
# Out:
# ✅ PROSES SELESAI. Dataset final berisi 18344 pemain modern siap digunakan.
# ✅ File berhasil disimpan sebagai artifact di: ../data/processed/mercato_engineered_data.csv
#                   name    position  total_minutes  goals_per_90  \
# 1         James Milner    Midfield        26708.0          0.13
# 2         Óscar Ustari  Goalkeeper          630.0          0.00
# 3  Anastasios Tsokanis    Midfield        21057.0          0.03
# 4        Jonas Hofmann    Midfield        22111.0          0.28
# 5           Pepe Reina  Goalkeeper        31800.0          0.00
#
#    assists_per_90  market_value_in_eur
# 1            0.24             750000.0
# 2            0.00             600000.0
# 3            0.03             200000.0
# 4            0.34            2000000.0
# 5            0.01             600000.0

# %%
# 1. DATA SCOPING (FILTERING)
df_modern_players = df_players[df_players['last_season'] >= 2024].copy()

print(f"Jumlah seluruh pemain historis: {len(df_players)}")
print(f"Jumlah pemain modern (setelah filter): {len(df_modern_players)}")

# 2. AGREGASI DATA STATISTIK
df_stats_summary = df_appearances.groupby('player_id').agg(
    total_minutes=('minutes_played', 'sum'),
    total_goals=('goals', 'sum'),
    total_assists=('assists', 'sum'),
    total_yellow_cards=('yellow_cards', 'sum'),
    total_red_cards=('red_cards', 'sum')
).reset_index()

# 3. DATA INTEGRATION (MERGE)
df_merged = pd.merge(df_modern_players, df_stats_summary, on='player_id', how='left')

df_merged.fillna({'total_minutes': 0, 'total_goals': 0, 'total_assists': 0, 
                  'total_yellow_cards': 0, 'total_red_cards': 0}, inplace=True)

df_merged[['player_id', 'name', 'last_season', 'total_minutes', 'total_goals', 'total_assists']].head()
# Out:
# Jumlah seluruh pemain historis: 47702
# Jumlah pemain modern (setelah filter): 25623
#    player_id                 name  last_season  total_minutes  total_goals  \
# 0       2989       Paolo Guerrero         2025            0.0          0.0
# 1       3333         James Milner         2025        26708.0         39.0
# 2       3755         Óscar Ustari         2024          630.0          0.0
# 3       5336  Anastasios Tsokanis         2025        21057.0          7.0
# 4       7161        Jonas Hofmann         2025        22111.0         70.0
#
#    total_assists
# 0            0.0
# 1           70.0
# 2            0.0
# 3            6.0
# 4           83.0
